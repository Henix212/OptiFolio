# %% [markdown]
# # Data Visualization
#
# This notebook provides exploratory visualizations of financial data: prices, volumes, returns, and volatility. The goal is to get a quick overview of the time series to spot trends, anomalies, and prepare further analysis.

# %% [markdown]
# ## Prerequisites
#
# Libraries used: `pandas` and `matplotlib`.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Load data
#
# Read CSV files for each dataset and ensure the `Date` column is parsed as a `datetime` type and set as the DataFrame index so the x-axis displays dates properly.

# %%
prices = pd.read_csv("../data/cleaned/prices/prices.csv")
volumes = pd.read_csv("../data/cleaned/prices/volumes.csv")
returns = pd.read_csv("../data/cleaned/returns/returns.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       2 volumes = pd.read_csv("../data/cleaned/prices/volumes.csv")
#       3 returns = pd.read_csv("../data/cleaned/returns/returns.csv")
# ----> 4 volatility = pd.read_csv("../data/cleaned/volatility/volatility.csv")
#
# File ~/Documents/Finance/projet/OptiFolio/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Documents/Finance/projet/OptiFolio/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Documents/Finance/projet/OptiFolio/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Documents/Finance/projet/OptiFolio/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Documents/Finance/projet/OptiFolio/.venv/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/cleaned/volatility/volatility.csv'

# %% [markdown]
# ### Prices
#
# For each ticker: convert `Date` to `datetime` if necessary, set it as the index, sort chronologically, and plot each ticker in its own subplot. Rotate x-axis labels and apply `tight_layout` to improve readability.

# %%
prices["Date"] = pd.to_datetime(prices['Date'], format='%Y-%m-%d') 
prices.set_index('Date', inplace=True)
prices.sort_index(inplace=True)

prices.plot(subplots=True, figsize=(30, 15), xlabel="Date", ylabel="Returns"); plt.legend(loc='best')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 prices["Date"] = pd.to_datetime(prices['Date'], format='%Y-%m-%d')
#       2 prices.set_index('Date', inplace=True)
#       3 prices.sort_index(inplace=True)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ### Volumes
#
# Volume charts help detect spikes in activity, which often precede or confirm price movements.

# %%
volumes["Date"] = pd.to_datetime(volumes['Date'], format='%Y-%m-%d') 
volumes.set_index('Date', inplace=True)
volumes.sort_index(inplace=True)

volumes.plot(subplots=True, figsize=(30, 15)); plt.legend(loc='best')

# %% [markdown]
# ### Returns
#
# Returns allow analysis of performance and risk. They are sensitive to extreme values

# %%
returns["Date"] = pd.to_datetime(returns['Date'], format='%Y-%m-%d') 
returns.set_index('Date', inplace=True)
returns.sort_index(inplace=True)

returns.plot(subplots=True, figsize=(30, 15), use_index = True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)
