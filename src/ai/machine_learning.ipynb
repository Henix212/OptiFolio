# %%
import pandas as pd
import torch as th
import os

# %%
BASE_DIR = os.path.abspath(os.path.join(os.getcwd(), "../../.."))
DATASET_DIR = os.path.join(BASE_DIR,'QuantPortfeuille','datasets')

PRICES_DIR = os.path.join(DATASET_DIR,'marketData','adj_close_prices.csv')
VOLUME_DIR = os.path.join(DATASET_DIR,'marketData','volume.csv')
WEIGHTS_DIR = os.path.join(DATASET_DIR,'groundTruth','weights.csv')

# %%
prices = pd.read_csv(PRICES_DIR,sep=',')

volume = pd.read_csv(VOLUME_DIR,sep=',')

weights = pd.read_csv(WEIGHTS_DIR,sep=',')['Weights'].to_list() # EEM | EFA | GLD | QQQ | SPY | TLT

# %% [markdown]
# Préparation des données
